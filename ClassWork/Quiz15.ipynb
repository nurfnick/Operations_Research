# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Operations_Research/blob/main/ClassWork/Quiz15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

p = [math.comb(12,3),math.comb(12,2)*math.comb(3,1),math.comb(12,1)*math.comb(3,2),math.comb(3,3)]
p = [x/sum(p) for x in p]
print(p)
# Out:
# [0.4835164835164835, 0.4351648351648352, 0.07912087912087912, 0.002197802197802198]

# %%
sum([i*p[i] for i in range(4)])
# Out:
# 0.6

# %%
3*3/15
# Out:
# 0.6

# %%
3*0.1
# Out:
# 0.30000000000000004
