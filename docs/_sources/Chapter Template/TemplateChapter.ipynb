# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Operations_Research/blob/main/TemplateChapter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter Title

# %% [markdown]
# ## Introduction/Motivation

# %% [markdown]
# ## Theory

# %% [markdown]
# Use **bold** for terms that you are defining.

# %% [markdown]
# ## Examples

# %% [markdown]
# ### Example 1

# %% [markdown]
# ### Example 2

# %% [markdown]
# ## References
#
# *How to Solve It* **G. Polya** Second Edition Princeton University Press 1957
#
# *Thinking Mathematically* **J. Mason** Addison-Wesley Publishing Company 1985
#
# *Grit: The Power of Passion and Perseverance* **A. Duckworth** ‎ Scribner Book Company 2016

# %% [markdown]
# ## Problems

# %% [markdown]
# ## Project Idea

# %% [markdown]
# ### Authors

# %% [markdown]
# Principal authors of this chapter were: [N.C.Jacob](https://github.com/nurfnick), but you!
#
# Contributions were made by:
