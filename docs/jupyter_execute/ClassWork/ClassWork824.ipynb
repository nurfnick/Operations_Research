# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Operations_Research/blob/main/ClassWork824.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math 

def f(x,a):
  return a*np.log(a/x)-a+x

# %%
f(1,1)
# Out:
# 0.0

# %%
math.log(math.e)
# Out:
# 1.0

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(.1,20,.01)
f(x,2)
for a in range(1,10):
  plt.plot(x,f(x,a))

plt.show()

# %%
A= np.array([[1,1],[1,-2]])
b = np.array([3,4])

sol = np.linalg.solve(A,b)

# %%
A @ sol
# Out:
# array([3., 4.])

# %%
np.linalg.inv(A)@b
# Out:
# array([ 3.33333333, -0.33333333])

# %%
C = np.array([[1,1,1],[1,-1,0],[0,1,1]])
d = np.array([3,5,2])

np.linalg.solve(C,d)
# Out:
# array([ 1., -4.,  6.])
